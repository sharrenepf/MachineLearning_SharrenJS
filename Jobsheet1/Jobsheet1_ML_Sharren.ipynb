# %% [markdown]
# <a href="https://colab.research.google.com/github/sharrenepf/MachineLearning_SharrenJS/blob/main/Jobsheet1_ML_Sharren.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sharren Elvaretta (244107020191)
#
# Jobsheet 1 Praktikum 1

# %%
# !pip install mne
