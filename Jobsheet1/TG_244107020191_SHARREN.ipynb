# %% [markdown]
# Sharren Elvaretta
#
# Jobsheet 1 Tugas Praktikum 1

# %%
# !pip install PyPREP
# Out:
# ...
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.7 MB 3.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/7.7 MB 3.3 MB/s eta 0:00:02
#    -------- ------------------------------- 1.6/7.7 MB 2.8 MB/s eta 0:00:03
#    ------------ --------------------------- 2.4/7.7 MB 2.8 MB/s eta 0:00:02
#    --------------- ------------------------ 2.9/7.7 MB 2.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.4/7.7 MB 2.7 MB/s eta 0:00:02
#    -------------------- ------------------- 3.9/7.7 MB 2.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.5/7.7 MB 2.7 MB/s eta 0:00:02
#    --------------------------- ------------ 5.2/7.7 MB 2.7 MB/s eta 0:00:01
#    ------------------------------ --------- 5.8/7.7 MB 2.7 MB/s eta 0:00:01
#    -------------------------------- ------- 6.3/7.7 MB 2.8 MB/s eta 0:00:01
# ...

# %%
# !pip install Scipy

# %%
# !pip install wandb
# Out:
# ...
#    ---------------------------------------- 0.0/24.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.1 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.1 MB 892.3 kB/s eta 0:00:27
#     --------------------------------------- 0.5/24.1 MB 892.3 kB/s eta 0:00:27
#    - -------------------------------------- 0.8/24.1 MB 933.0 kB/s eta 0:00:25
#    - -------------------------------------- 1.0/24.1 MB 931.0 kB/s eta 0:00:25
#    -- ------------------------------------- 1.3/24.1 MB 920.9 kB/s eta 0:00:25
#    -- ------------------------------------- 1.3/24.1 MB 920.9 kB/s eta 0:00:25
#    -- ------------------------------------- 1.6/24.1 MB 803.1 kB/s eta 0:00:29
#    -- ------------------------------------- 1.6/24.1 MB 803.1 kB/s eta 0:00:29
#    --- ------------------------------------ 1.8/24.1 MB 826.9 kB/s eta 0:00:27
# ...

# %%
# !pip install pyECG
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
# ...
